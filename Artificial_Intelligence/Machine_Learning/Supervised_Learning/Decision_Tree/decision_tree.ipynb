# %% [markdown]
# # Decision Tree - Cây quyết định
#
# ## 1. Giới thiệu
# Decision Tree (Cây quyết định) là một mô hình học có giám sát, được sử dụng cho các bài toán phân loại (Classification) và hồi quy (Regression).
# Nó hoạt động bằng cách chia dữ liệu thành các tập con nhỏ hơn dựa trên các tiêu chí toán học như Entropy, Information Gain, hoặc Gini Index.
#
# ## 2. Cách hoạt động của Decision Tree
# Quá trình xây dựng Decision Tree gồm 3 bước chính:
#
# 1. **Chọn thuộc tính tốt nhất để phân chia dữ liệu**
#    - Dựa vào các tiêu chí như **Information Gain, Gini Index, hoặc Variance Reduction**.
# 2. **Tiếp tục phân chia dữ liệu con cho đến khi đạt điều kiện dừng**
#    - Điều kiện có thể là tất cả dữ liệu trong một nhánh thuộc cùng một lớp hoặc độ sâu tối đa của cây.
# 3. **Cắt tỉa cây (Pruning)**
#    - Giảm độ phức tạp của cây để tránh overfitting.
#
# ## 3. Các công thức toán học quan trọng
#
# ### 3.1 Entropy (Độ hỗn loạn của dữ liệu)
# Entropy đo lường độ không chắc chắn của một tập dữ liệu:
#
# $$
# H(S) = - \sum_{i=1}^{c} p_i \log_2 p_i
# $$
#
# - \( S \) là tập dữ liệu.
# - \( c \) là số lớp.
# - \( p_i \) là xác suất xuất hiện của lớp \( i \).
#
# 👉 Entropy càng nhỏ, dữ liệu càng thuần nhất.
#
# ### 3.2 Information Gain (Lợi ích thông tin)
# Dùng để chọn thuộc tính tốt nhất khi chia tập dữ liệu:
#
# $$
# IG(S, A) = H(S) - \sum_{v \in Values(A)} \frac{|S_v|}{|S|} H(S_v)
# $$
#
# ### 3.3 Gini Index (Chỉ số Gini - Dùng trong CART)
#
# $$
# Gini(S) = 1 - \sum_{i=1}^{c} p_i^2
# $$
#
# 👉 Gini càng nhỏ, dữ liệu càng thuần nhất.
#
# ### 3.4 Gain Ratio (C4.5 sử dụng - Điều chỉnh Information Gain)
# Gain Ratio giúp cân bằng việc chọn thuộc tính hợp lý hơn:
#
# $$
# GainRatio(S, A) = \frac{IG(S, A)}{SplitInfo(S, A)}
# $$
#
# Với:
#
# $$
# SplitInfo(S, A) = - \sum_{v \in Values(A)} \frac{|S_v|}{|S|} \log_2 \frac{|S_v|}{|S|}
# $$
#
# ### 3.5 Variance Reduction (Dùng cho hồi quy - Regression Tree)
# Trong hồi quy, ta cần giảm phương sai của dữ liệu thay vì Entropy hoặc Gini. Công thức:
#
# $$
# VR = Var(S) - \sum_{v \in Values(A)} \frac{|S_v|}{|S|} Var(S_v)
# $$
#
# 👉 Cây hồi quy (Regression Tree) sẽ chọn thuộc tính có Variance Reduction lớn nhất để chia nhánh.
#
# ## 4. Ứng dụng thực tế của Decision Tree
# - Dự đoán bệnh tật dựa trên triệu chứng.
# - Chấm điểm tín dụng và phân loại khách hàng.
# - Phát hiện gian lận trong giao dịch tài chính.
# - Nhận diện spam email.
